# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
D1 = pd.read_csv("Real_AQI_Combine.csv")

# %%
D1
# Out:
#          T    TM    Tm     SLP     H   VV     V    VM      PM 2.5
# 0      7.4   9.8   4.8  1017.6  93.0  0.5   4.3   9.4  219.720833
# 1      7.8  12.7   4.4  1018.5  87.0  0.6   4.4  11.1  182.187500
# 2      6.7  13.4   2.4  1019.4  82.0  0.6   4.8  11.1  154.037500
# 3      8.6  15.5   3.3  1018.7  72.0  0.8   8.1  20.6  223.208333
# 4     12.4  20.9   4.4  1017.3  61.0  1.3   8.7  22.2  200.645833
# ...    ...   ...   ...     ...   ...  ...   ...   ...         ...
# 1088  18.1  24.0  11.2  1015.4  56.0  1.8  15.9  25.9  288.416667
# 1089  17.8  25.0  10.7  1015.8  54.0  2.3   9.4  22.2  256.833333
# 1090  13.9  24.5  11.4  1015.0  95.0  0.6   8.7  14.8  169.000000
# 1091  16.3  23.0   9.8  1016.9  78.0  1.1   7.4  16.5  186.041667
# 1092  16.3  23.4   9.0  1017.3  68.0  1.3   7.8  18.3  185.583333
#
# [1093 rows x 9 columns]

# %%
D1.shape
# Out:
# (1093, 9)

# %%
D1.columns
# Out:
# Index(['T', 'TM', 'Tm', 'SLP', 'H', 'VV', 'V', 'VM', 'PM 2.5'], dtype='object')

# %%
D1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1093 entries, 0 to 1092
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   T       1093 non-null   float64
#  1   TM      1093 non-null   float64
#  2   Tm      1093 non-null   float64
#  3   SLP     1093 non-null   float64
#  4   H       1093 non-null   float64
#  5   VV      1093 non-null   float64
#  6   V       1093 non-null   float64
#  7   VM      1093 non-null   float64
#  8   PM 2.5  1092 non-null   float64
# dtypes: float64(9)
# memory usage: 77.0 KB

# %%
D1.isnull().sum()
# Out:
# T         0
# TM        0
# Tm        0
# SLP       0
# H         0
# VV        0
# V         0
# VM        0
# PM 2.5    1
# dtype: int64

# %%
# handle missing value 
d2 = D1['PM 2.5'].mean()

# %%
d2
# Out:
# 109.09098366910867

# %%
D2 = D1.fillna(D1.mean())

# %%
D2.isnull().sum()
# Out:
# T         0
# TM        0
# Tm        0
# SLP       0
# H         0
# VV        0
# V         0
# VM        0
# PM 2.5    0
# dtype: int64

# %%
# check missing data by heatmap 
plt.figure(figsize=(10,4))
sns.heatmap(D2.isnull(),annot=True,cbar=True)
plt.show()

# %%
D2.corr()
# Out:
#                T        TM        Tm       SLP         H        VV         V  \
# T       1.000000  0.967570  0.953703 -0.881698 -0.510593  0.640738  0.302349
# TM      0.967570  1.000000  0.891970 -0.823447 -0.588017  0.606746  0.293309
# Tm      0.953703  0.891970  1.000000 -0.917557 -0.288647  0.577382  0.296546
# SLP    -0.881698 -0.823447 -0.917557  1.000000  0.242307 -0.518015 -0.330155
# H      -0.510593 -0.588017 -0.288647  0.242307  1.000000 -0.465514 -0.380805
# VV      0.640738  0.606746  0.577382 -0.518015 -0.465514  1.000000  0.377029
# V       0.302349  0.293309  0.296546 -0.330155 -0.380805  0.377029  1.000000
# VM      0.288292  0.297590  0.267249 -0.311231 -0.362632  0.342650  0.775715
# PM 2.5 -0.630705 -0.567378 -0.673415  0.622410  0.137802 -0.573864 -0.268498
#
#               VM    PM 2.5
# T       0.288292 -0.630705
# TM      0.297590 -0.567378
# Tm      0.267249 -0.673415
# SLP    -0.311231  0.622410
# H      -0.362632  0.137802
# VV      0.342650 -0.573864
# ...

# %%
corr = D2.corr()

# %%
## Correlation
import seaborn as sns
import matplotlib.pyplot as plt
#get correlations of each features in dataset
corrmat = corr
top_corr_features = corrmat.index
plt.figure(figsize=(20,20))
#plot heat map
g=sns.heatmap(corr[top_corr_features].corr(),annot=True,cmap="RdYlGn")

# %%
sns.pairplot(D2, diag_kind='hist', corner=False)
# Out:
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
plt.figure(figsize=(10,20))
D2.hist(bins=15,grid=True)
plt.show()

# %%
## Handle the Duplicated values

D2.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1088     True
# 1089     True
# 1090     True
# 1091     True
# 1092     True
# Length: 1093, dtype: bool

# %%
D2[D2.duplicated()].shape
# Out:
# (362, 9)

# %%
D2[D2.duplicated()]
# Out:
#          T    TM    Tm     SLP     H   VV     V    VM      PM 2.5
# 731   16.9  25.1   6.6  1021.3  65.0  1.1   2.0   7.6  284.795833
# 732   15.5  24.1   7.7  1021.0  71.0  1.1   3.5  11.1  219.720833
# 733   14.9  22.8   8.0  1018.4  73.0  1.1   5.9  13.0  182.187500
# 734   18.3  24.7  11.5  1018.1  85.0  0.5   1.1   7.6  154.037500
# 735   16.5  24.7  12.0  1017.4  82.0  0.6   8.0  13.0  223.208333
# ...    ...   ...   ...     ...   ...  ...   ...   ...         ...
# 1088  18.1  24.0  11.2  1015.4  56.0  1.8  15.9  25.9  288.416667
# 1089  17.8  25.0  10.7  1015.8  54.0  2.3   9.4  22.2  256.833333
# 1090  13.9  24.5  11.4  1015.0  95.0  0.6   8.7  14.8  169.000000
# 1091  16.3  23.0   9.8  1016.9  78.0  1.1   7.4  16.5  186.041667
# 1092  16.3  23.4   9.0  1017.3  68.0  1.3   7.8  18.3  185.583333
#
# [362 rows x 9 columns]

# %%
clean3 = D2.drop_duplicates()

# %%
clean3.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 726    False
# 727    False
# 728    False
# 729    False
# 730    False
# Length: 731, dtype: bool

# %%
# check corr in between x='T',y='PM 2.5' 
clean3.plot.scatter(x='T',y='PM 2.5')
# Out:
# <Axes: xlabel='T', ylabel='PM 2.5'>

# %%
# check corr in between (x='T',y='TM')
clean3.plot.scatter(x='T',y='TM')
# Out:
# <Axes: xlabel='T', ylabel='TM'>

# %%
# Handle the outlier

# %%
clean3.columns
# Out:
# Index(['T', 'TM', 'Tm', 'SLP', 'H', 'VV', 'V', 'VM', 'PM 2.5'], dtype='object')

# %%
# hist plot
column_name  = ['T', 'TM', 'Tm', 'SLP', 'H', 'VV', 'V', 'VM', 'PM 2.5']

# %%
clean3['SLP'].plot.box()
# Out:
# <Axes: >

# %%
clean3.boxplot(column='Tm')
# Out:
# <Axes: >

# %%
### Create a box plot for each specified column outlier 
plt.figure(figsize=(15,10))
clean3[column_name].plot(kind='box', subplots=True, layout=(1, 9), figsize=(15,5), sharey=False)
plt.tight_layout()
plt.show()

# %% [raw]
# # Specify the columns for which you want to handle outliers
# # column_name  = ['T', 'TM', 'Tm', 'SLP', 'H', 'VV', 'V', 'VM', 'PM 2.5']
# # Function to identify outliers using the IQR method
# def identify_outliers(clean3, columns):
#     outliers = {}
#     for column in columns:
#         Q1 = clean3[column].quantile(0.25)
#         Q3 = clean3[column].quantile(0.75)
#         IQR = Q3 - Q1
#         lower_bound = Q1 - 1.5 * IQR
#         upper_bound = Q3 + 1.5 * IQR
#         outliers[column] = clean3[(clean3[column] < lower_bound) | (clean3[column] > upper_bound)]
#     return outliers
#
# # Identify outliers
# outliers = identify_outliers(clean3, column_name)
# for column, outlier_data in outliers.items():
#     print(f"Outliers in {column}:")
#     print(outlier_data)
#
# # Function to handle outliers by capping them
# def cap_outliers(clean3, columns):
#     for column in columns:
#         Q1 = clean3[column].quantile(0.25)
#         Q3 = clean3[column].quantile(0.75)
#         IQR = Q3 - Q1
#         lower_bound = Q1 - 1.5 * IQR
#         upper_bound = Q3 + 1.5 * IQR
#         clean3[column] = np.where(clean3[column] < lower_bound, lower_bound, clean3[column])
#         clean3[column] = np.where(clean3[column] > upper_bound, upper_bound, clean3[column])
#     return clean3
#
# # Handle outliers by capping them
# df_cleaned = cap_outliers(clean3, column_name)
#
# # Plot box plots for cleaned data
# plt.figure(figsize=(15, 10))
# df_cleaned[column_name].plot(kind='box', subplots=True, layout=(1, 9), figsize=(15, 5), sharey=False)
# plt.tight_layout()
# plt.show()

# %% [raw]
# Inter Quantile Range
# 75%-25% values in a dataset
# Steps
# 1. Arrange the data in increasing order
# 2. Calculate first(q1) and third quartile(q3)
# 3. Find interquartile range (q3-q1)
# 4.Find lower bound q1*1.5
# 5.Find upper bound 31.5

# %% [markdown]
# ## Handeling Outlier by Using IQR Inter Quantile Range

# %%
# Identify the first quartile (Q1), third quartile (Q3), and interquartile range (IQR) for the specified columns

Q1 = clean3[column_name].quantile(0.25) # Quantile is a function 
Q3 = clean3[column_name].quantile(0.75)
IQR = Q3 - Q1

# Calculate the lower and upper bounds for outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Cap the outliers for each column
clean3[column_name] = np.where(clean3[column_name] < lower_bound, lower_bound, clean3[column_name])
clean3[column_name] = np.where(clean3[column_name] > upper_bound, upper_bound, clean3[column_name])
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_14804\2958883931.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean3[column_name] = np.where(clean3[column_name] < lower_bound, lower_bound, clean3[column_name])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_14804\2958883931.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean3[column_name] = np.where(clean3[column_name] > upper_bound, upper_bound, clean3[column_name])

# %%
# Plot box plots for cleaned data
plt.figure(figsize=(15, 10))
clean3[column_name].plot(kind='box', subplots=True, layout=(1, 9), figsize=(15, 5), sharey=False)
plt.tight_layout()
plt.show()

# %%
clean3
# Out:
#         T      TM    Tm     SLP     H   VV     V    VM      PM 2.5
# 0     7.4  13.525   4.8  1017.6  93.0  0.5   4.3   9.4  219.720833
# 1     7.8  13.525   4.4  1018.5  87.0  0.6   4.4  11.1  182.187500
# 2     6.7  13.525   2.4  1019.4  82.0  0.6   4.8  11.1  154.037500
# 3     8.6  15.500   3.3  1018.7  72.0  0.8   8.1  20.6  223.208333
# 4    12.4  20.900   4.4  1017.3  61.0  1.3   8.7  22.2  200.645833
# ..    ...     ...   ...     ...   ...  ...   ...   ...         ...
# 726  18.1  24.000  11.2  1015.4  56.0  1.8  15.9  25.9  288.416667
# 727  17.8  25.000  10.7  1015.8  54.0  2.3   9.4  22.2  256.833333
# 728  13.9  24.500  11.4  1015.0  95.0  0.6   8.7  14.8  169.000000
# 729  16.3  23.000   9.8  1016.9  78.0  1.1   7.4  16.5  186.041667
# 730  16.3  23.400   9.0  1017.3  68.0  1.3   7.8  18.3  185.583333
#
# [731 rows x 9 columns]

# %%
# Scaling the feature by using standerdization and normaliation

# %%
x = clean3.drop('PM 2.5',axis=1)
y = clean3.iloc[:,-1]

print(type(x))
print(type(y))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.series.Series'>

# %%
sns.distplot(y)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_14804\476133659.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(y)
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='PM 2.5', ylabel='Density'>

# %% [markdown]
# Feature Importance

# %%
from sklearn.ensemble import ExtraTreesRegressor
Feature = ExtraTreesRegressor()

# %%
Feature.fit(x,y)
# Out:
# ExtraTreesRegressor()

# %%
#plot graph of feature importances for better visualization
feat_importances = pd.Series(Feature.feature_importances_, index=x.columns)
feat_importances.nlargest(5).plot(kind='barh')
plt.show()

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error,mean_squared_error,root_mean_squared_error
from sklearn.linear_model import LinearRegression

# split the data set into train and test
x_train,x_test,y_train,y_test = train_test_split (x,y, test_size=0.25,random_state=42)

# %% [markdown]
# Feature Scalling

# %%
standerd_scaler = StandardScaler()

# %%
X_train_std = standerd_scaler.fit_transform(x_train)
X_std_test = standerd_scaler.transform(x_test)

# %% [markdown]
# Linear Regrssion

# %%
# Model selection ---Linear regression 
linear_model = LinearRegression()
linear_model.fit(X_train_std,y_train)
# Out:
# LinearRegression()

# %%
# predicted value
L1_pred = linear_model.predict(X_std_test)

# %%
L1_pred
# Out:
# array([194.92988906,  85.41416239,  31.47952341,  62.91314362,
#         45.80592982, 201.68595789,  73.12809368, 139.32366808,
#        205.06990825,  93.90599422, 181.01362933, 144.25525406,
#        167.62161679,  39.99421048, 103.73990553,  36.99099697,
#         98.25985467,  44.93760536, 197.05809079, 205.78047433,
#         58.63169073, 243.25368938,  42.05027212, 124.55617301,
#        125.43758712,  70.71478075,  44.08884168,  38.28892101,
#         81.15327555, 207.53967469, 155.98389426,  66.17021851,
#         61.21857331, 116.6950816 ,  78.01080368,  90.37143644,
#         78.30173345, 112.79759216,  56.43196526, 158.01634333,
#         47.96716929,  55.68013951, 135.4082677 , 129.78028108,
#        168.26437042, 161.86503238, 165.15103205,  49.36919654,
#        106.47207462,  64.08123544, 110.3298966 , 212.65459484,
#        181.70674317, 227.8712991 , 137.22377403,  94.91990462,
#         76.86552316,  79.15704728, 135.99594526, 128.29527755,
# ...

# %%
print('intercept',linear_model.intercept_)

print('coeff',linear_model.coef_)
# Out:
# intercept 107.53698552372704
# coeff [ 17.21674796  -3.71174057 -50.77575494  -1.18121982 -15.51542187
#  -37.31590188  -8.31978625   0.41925826]

# %%
## Cross validation 
from sklearn.model_selection import cross_val_score
cross_val = cross_val_score(linear_model,x,y,cv=5)

print(cross_val)
# Out:
# [0.52308789 0.5023199  0.65658706 0.58330133 0.17912804]

# %%
cross_val.mean()
# Out:
# 0.4888848427974605

# %%
plt.scatter(x=y_test,y=L1_pred)
plt.xlabel('Actual Value')
plt.ylabel('Predicted Value')

plt.title('Actual Value Vs Predicted Value ')
# Out:
# Text(0.5, 1.0, 'Actual Value Vs Predicted Value ')

# %%
## Evalution model to check the performance of the model
MAE = mean_absolute_error(L1_pred,y_test)
MSE= mean_squared_error(L1_pred,y_test)
RMSE =
# Out:
#   Cell In[70], line 4
#     RMSE =
#           ^
# SyntaxError: invalid syntax

# %%
from sklearn import metrics
MAE = metrics.mean_absolute_error(L1_pred,y_test)
MSE= metrics.mean_squared_error(L1_pred,y_test)
RMSE = np.square(metrics.mean_squared_error(L1_pred,y_test))

print('MAE',MAE)
print('MSE',MSE)
print('RMSE',RMSE)
# Out:
# MAE 38.46795688494942
# MSE 2843.34359442938
# RMSE 8084602.795982587

# %%
# import pickle 
# open a file, where you ant to store the data
# file = open('regression_model.pkl', 'wb')

# dump information to that file
# pickle.dump(regressor, file)

# %%
# creat the new clean csv file of AQI
clean3.to_csv("clean_AQI_csv")
